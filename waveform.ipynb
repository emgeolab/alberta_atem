# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fname = f"/Users/sgkang09/Dropbox/ags_data/DIG_2017_0001/Flightline_data/11-024 - TDEM Reference Wave Form.xlsx"
df_tmp = pd.read_excel(fname, skiprows=4)

n_times = len(df_tmp.values[0,3:])
times = np.arange(n_times) * df_tmp.values[0,2] * 1e-6

# %%
# %matplotlib widget

# %%
df_tmp.head(3)
# Out:
#   Flight    Emfid  Gate Width (µs)    I1_Raw     I2_Raw     I3_Raw     I4_Raw  \
# 0      1  1569348            27.78  2.606587  10.233216  26.369557  40.229206
# 1      1  1569349            27.78 -2.577853 -10.354733 -26.440515 -40.311570
# 2      2   933560            27.78  8.112259  24.113483  38.087082  52.971620
#
#       I5_Raw     I6_Raw     I7_Raw  ...  I191_Raw  I192_Raw  I193_Raw  \
# 0  55.197315  69.376988  84.119940  ... -3.431764 -3.502831 -3.366728
# 1 -55.270686 -69.476461 -84.218096  ...  3.499980  3.574996  3.483858
# 2  67.214246  81.909270  96.203332  ... -3.521805 -3.381534 -3.514676
#
#    I194_Raw  I195_Raw  I196_Raw  I197_Raw  I198_Raw  I199_Raw  I200_Raw
# 0 -3.489780 -3.341942 -3.521256 -3.274713 -3.610969 -3.159995 -7.636061
# 1  3.603072  3.438892  3.623362  3.385591  3.686094  3.239288  7.813292
# 2 -3.343587 -3.541985 -3.309588 -3.624020 -3.222508 -3.827133 -5.257483
#
# [3 rows x 203 columns]

# %%
fig = plt.figure()
# for ii in range(df_tmp.shape[0]):
ii = 10
if df_tmp.values[ii,50]<0:
    sign = -1
else:
    sign = 1
# plt.plot(times, df_tmp.values[4,3:], '.-')
plt.plot(times, sign*df_tmp.values[ii,3:], '-', color='k')
# ylim = plt.ylim()
ylim = (-8, 0)
plt.plot(1.74e-3 * np.ones(2), ylim, '')
plt.plot(1.74e-3-0.84e-3 * np.ones(2), ylim, '')
plt.xlim(1.74e-3-1e-4, 1.74e-3+3e-4)
plt.ylim(ylim)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Question is: how to address left over currents at the very early off times.
